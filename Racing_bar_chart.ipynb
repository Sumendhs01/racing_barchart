# %%
pip install sjvisualizer-0.0.3-py2.py3-none-any.whl
# Out:
# Processing c:\users\sumen\sjvisualizer-0.0.3-py2.py3-none-any.whl
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# WARNING: Requirement 'sjvisualizer-0.0.3-py2.py3-none-any.whl' looks like a filename, but the file does not exist
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\sumen\\sjvisualizer-0.0.3-py2.py3-none-any.whl'
#
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)

# %%
pip freeze | grep sjvisualizer
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install sjvisualizer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (c:\users\sumen\anaconda3\lib\site-packages)

# %%
from sjvisualizer import Canvas
from sjvisualizer import DataHandler
from sjvisualizer import BarRace
import time
import json

# %%
def main(fps = 60,duration = 0.35):
    number_of_frames = duration*60*fps
    
    #load colours
    with open("C:/Users/sumen/Desktop/colors.json") as f:
        colors = json.load(f)
        
    #load data from excel
    df = DataHandler.DataHandler(excel_file="C:/Users/sumen/Desktop/Nuclear_warheads 1945-2022 per country.xlsx", number_of_frames = number_of_frames).df
    
    canvas = Canvas.canvas()
    
    #add bar chart
    bar_chart = BarRace.bar_race(canvas=canvas.canvas, df=df, colors=colors)
    canvas.add_sub_plot(bar_chart)
    
    #add static text
    canvas.add_title("Nuclear_warheads 1945-2022 per country", color=(0,132,255))

    
    #add time indication
    canvas.add_time(df=df, time_indicator="month")
    
    #save colors for next run
    with open("colors.json", "w") as file:
        json.dump(colors, file, indent=4)
    
    canvas.play(fps=fps)

# %%
if __name__== "__main__":
    main()
# Out:
# Loading cashed data frame _pandas_cache\Users1260.xlsx
# No image for United States
# No image for Russia
# No image for United Kingdom
# No image for France
# No image for China
# No image for Israel
# No image for India
# No image for Pakistan
# No image for North Korea
# FPS: 1
# FPS: 59
# FPS: 58
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 58
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 58
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 58
# FPS: 59
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 57
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# ...
